# %%
import numpy as np
import pandas as pd
import panel as pn
import param
import matplotlib.pyplot as plt

# %%
out_df = pd.read_csv('./output/sim_data.csv')

# %%
out_df
# Out:
#        Simulation #  Day #  Step #  Minute #  Infected ID  Other ID  \
# 0                 0      0       0        24           10         0
# 1                 0      0       0        24           10         1
# 2                 0      0       0        24           10         2
# 3                 0      0       0        24           10         3
# 4                 0      0       0        24           10         4
# ...             ...    ...     ...       ...          ...       ...
# 21019             0      4       2        59           10        20
# 21020             0      4       2        59           10        21
# 21021             0      4       2        59           10        22
# 21022             0      4       2        59           10        23
# 21023             0      4       2        59           10        24
#
#        Close Range Transmission  Shared Room Transmission  \
# 0                  3.154159e-07              4.969397e-07
# ...
