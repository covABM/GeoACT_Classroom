# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
# %run av_run -wmr=True --n_sims=10
# Out:
# arguments received
# model instance generated
# {0: (5, 5), 1: (5, 23), 2: (5, 41), 3: (5, 59), 4: (5, 77), 5: (23, 5), 6: (23, 23), 7: (23, 41), 8: (23, 59), 9: (23, 77), 10: (41, 5), 11: (41, 23), 12: (41, 41), 13: (41, 59), 14: (41, 77), 15: (59, 5), 16: (59, 23), 17: (59, 41), 18: (59, 59), 19: (59, 77), 20: (77, 5), 21: (77, 23), 22: (77, 41), 23: (77, 59), 24: (77, 77)}
# Sims start
# overflow above
# overflow above
# 25\% complete ...
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# 50\% complete ...
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# ...
