# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
# %run av_run -wmr=True --n_sims=10
# Out:
# arguments received
# model instance generated
# Sims start
# overflow above
# overflow above
# 25\% complete ...
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# 50\% complete ...
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# overflow above
# 75\% complete ...
# ...
